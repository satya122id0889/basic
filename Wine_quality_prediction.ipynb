# %%
import pandas as pd
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers

# %%
wine_dataset = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv' , delimiter = ';')

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wine_dataset.shape
# Out:
# (4898, 12)

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wine_features = wine_dataset.copy()
wine_label = wine_dataset.pop('quality')

# %%
wine_features = np.array(wine_features)
wine_features
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  3.  ,  0.45,  8.8 ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  3.3 ,  0.49,  9.5 ],
#        [ 8.1 ,  0.28,  0.4 , ...,  3.26,  0.44, 10.1 ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  2.99,  0.46,  9.4 ],
#        [ 5.5 ,  0.29,  0.3 , ...,  3.34,  0.38, 12.8 ],
#        [ 6.  ,  0.21,  0.38, ...,  3.26,  0.32, 11.8 ]])

# %%
wine_model = tf.keras.Sequential([
    layers.Dense(64),
    layers.Dense(1)
])

# %%
wine_model.compile(loss = tf.keras.losses.MeanSquaredError(),
                      optimizer = tf.keras.optimizers.Adam())

# %%
wine_model.fit(wine_features, wine_label, epochs=10)
# Out:
# Epoch 1/10
# 154/154 [==============================] - 1s 2ms/step - loss: 27.9745
# Epoch 2/10
# 154/154 [==============================] - 0s 1ms/step - loss: 1.9556
# Epoch 3/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.8882
# Epoch 4/10
# 154/154 [==============================] - 0s 2ms/step - loss: 0.7715
# Epoch 5/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.7515
# Epoch 6/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.7401
# Epoch 7/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.7421
# Epoch 8/10
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6975
# Epoch 9/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6844
# Epoch 10/10
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6629
